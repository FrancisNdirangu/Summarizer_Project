# %%
import pandas as pd
import numpy as np
import os

# %%
df_1 = pd.read_csv("datasets/1.csv")
df_1.head()
# Out:
#                                                title  \
# 0                                           Untitled
# 1                                      Research Debt
# 2                                           Untitled
# 3  Gemini Deep Think learns math, wins gold medal...
# 4                                           Untitled
#
#                                                  url  word_count  \
# 0  https://aibusiness.com/language-models/how-wim...           0
# 1             https://distill.pub/2017/research-debt        1787
# 2  https://aibusiness.com/nvidia/nvidia-dethrones...           0
# 3  https://arstechnica.com/ai/2025/07/google-deep...         967
# 4  https://aibusiness.com/computer-vision/compute...           0
#
#                                              content
# 0                                                NaN
# 1  Chris Olah Google Brain Shan Carter Google Bra...
# 2                                                NaN
# ...

# %%
df_2= pd.read_csv("datasets/2.csv")
df_2.head()
# Out:
#                                                title  \
# 0                        Thank you for your patience
# 1                         Why Doesn’t My Model Work?
# 2                Ask a Techspert: What is inference?
# 3                     The Artificiality of Alignment
# 4  What's Missing From LLM Chatbots: A Sense of P...
#
#                                                  url  word_count  \
# 0  https://www.microsoft.com/en-us/research/blog/...          14
# 1  https://thegradient.pub/why-doesnt-my-model-work/        3665
# 2  https://blog.google/technology/ai/ask-a-techsp...        1376
# 3  https://thegradient.pub/the-artificiality-of-a...        3789
# 4                    https://thegradient.pub/dialog/        2658
#
#                                              content
# 0  We are currently experiencing high demand. Ple...
# 1  Have you ever trained a model you thought was ...
# 2  Jun 23, 2025 Inference is a big part of what’s...
# ...

# %%
df_3= pd.read_csv("datasets/3.csv")
df_3.head()
# Out:
#                                                title  \
# 0  Study could lead to LLMs that are better at co...
# 1                             How we really judge AI
# 2  MIT Learn offers “a whole new front door to th...
# 3  Data quality for unbiased results: Preventing ...
# 4   Ethics-driven model auditing and bias mitigation
#
#                                                  url  word_count  \
# 0  https://news.mit.edu/2025/study-could-lead-llm...        1022
# 1  https://news.mit.edu/2025/how-we-really-judge-...         826
# 2  https://news.mit.edu/2025/mit-learn-offers-who...        1186
# 3  https://www.datasciencecentral.com/data-qualit...        1467
# 4  https://www.datasciencecentral.com/ethics-driv...        1669
#
#                                              content
# 0  Suggestions or feedback? Images for download o...
# 1  Suggestions or feedback? Previous imageNext im...
# 2  Suggestions or feedback? Previous imageNext im...
# ...

# %%
df_4= pd.read_csv("datasets/4.csv")
df_4.head()
# Out:
#                                                title  \
# 0  Bitcoin Price Analysis as a Tool for Blockchai...
# 1  Updates from the NeurIPS 2025 Position Paper T...
# 2  Tech giants split on EU AI code as compliance ...
# 3                                          Import AI
# 4          How to use AI to start an online business
#
#                                                  url  word_count  \
# 0  https://thedatascientist.com/bitcoin-price-ana...        1126
# 1  https://blog.neurips.cc/2025/06/06/updates-fro...         727
# 2  https://www.artificialintelligence-news.com/ne...        1074
# 3  https://jack-clark.net/2025/06/23/import-ai-41...        2190
# 4  https://www.artificialintelligence-news.com/ne...        1015
#
#                                              content
# 0  The Data Scientist For blockchain decision-mak...
# 1  Communications Chairs 20252025 Conference Barb...
# 2  AI News is part of the TechForge Publications ...
# ...

# %%
df_5= pd.read_csv("datasets/5.csv")
df_5.head()
# Out:
#                                                title  \
# 0  Spacecrafts Can Think for Themselves, Thanks t...
# 1  This “robot bird” flies at 45 mph through fore...
# 2  The Future of Fake: Why Artificial Intelligenc...
# 3  Google Expands Firebase Studio with AI Tools f...
# 4  AI Replaced My Job… So I Let It Manage My Sche...
#
#                                                  url  word_count  \
# 0  https://analyticsindiamag.com/ai-news-updates/...         551
# 1  https://www.sciencedaily.com/releases/2025/06/...         581
# 2  https://hackernoon.com/the-future-of-fake-why-...         647
# 3  https://analyticsindiamag.com/ai-news-updates/...         533
# 4  https://hackernoon.com/ai-replaced-my-job-so-i...         733
#
#                                              content
# 0  Micron Technologyclaims to have launched the i...
# 1  Unlike birds, which navigate unknown environme...
# 2  In 2025, the influence no longer belongs to hu...
# ...

# %%
df_ai_ml = pd.read_csv("datasets/ai_ml_articles.csv")
df_ai_ml.head()
# Out:
#                                                title  \
# 0  The Open Medical-LLM Leaderboard: Benchmarking...
# 1  Director of Machine Learning Insights [Part 2:...
# 2  Hands‑On with Agents SDK: Your First API‑Calli...
# 3  4M Models Scanned: Protect AI + Hugging Face 6...
# 4       Judge Arena: Benchmarking LLMs as Evaluators
#
#                                                  url  word_count  \
# 0  https://huggingface.co/blog/leaderboard-medica...        1359
# 1  https://huggingface.co/blog/ml-director-insigh...        2894
# 2  https://towardsdatascience.com/hands%e2%80%91o...        2387
# 3            https://huggingface.co/blog/pai-6-month        1250
# 4             https://huggingface.co/blog/arena-atla         517
#
#                                              content
# 0  Datasets, Tasks, and Evaluation SetupMedQAMedM...
# 1  Omar Rahman1. How has ML made a positive impac...
# 2  Publish AI, ML & data-science insights to a gl...
# ...

# %%
df_arxiv = pd.read_csv("datasets/arxiv_ai_abstracts.csv")
df_arxiv.head()
# Out:
#                                                Title  \
# 0  ThinkAct: Vision-Language-Action Reasoning via...
# 1  Semi-off-Policy Reinforcement Learning for Vis...
# 2  HOComp: Interaction-Aware Human-Object Composi...
# 3  MegaScience: Pushing the Frontiers of Post-Tra...
# 4  Rethinking LLM-Based RTL Code Optimization Via...
#
#                                              Content
# 0  Vision-language-action (VLA) reasoning tasks r...
# 1  Enhancing large vision-language models (LVLMs)...
# 2  While existing image-guided composition method...
# 3  Scientific reasoning is critical for developin...
# 4  Register Transfer Level(RTL) code optimization...

# %%
df_datascienceplus = pd.read_csv("datasets/datascienceplus_articles.csv")
df_datascienceplus.head()
# Out:
#                                                Title  \
# 0  Linking R and Python to retrieve financial dat...
# 1            An R alternative to pairs for -omics QC
# 2    Visualizing economic data with pretty worldmaps
# 3  How to Incorporate ML.Net With Algorithmic Tra...
# 4  How I selected my starting word for Wordle usi...
#
#                                                  URL                 Date  \
# 0  https://datascienceplus.com/linking-r-and-pyth...  2022-04-17T20:02:48
# 1  https://datascienceplus.com/an-r-alternative-t...  2022-03-27T20:23:19
# 2  https://datascienceplus.com/visualizing-econom...  2022-03-22T13:56:14
# 3  https://datascienceplus.com/how-to-incorporate...  2022-03-17T19:58:25
# 4  https://datascienceplus.com/how-i-selected-my-...  2022-02-23T20:19:34
#
#                                              Content
# 0  I am way more experienced with R than with Pyt...
# 1  The Problem:I've got a couple of problems with...
# ...

# %%
df_shyambhu=pd.read_csv("datasets/shyambhu_all_posts.csv")
df_shyambhu.head()
# Out:
#                                                title  \
# 0     Understanding LDA and QDA: A Comparative Guide
# 1  20 Must-Know Math Puzzles for Data Science Int...
# 2             A look in probability for data science
# 3  Interview Dialogue: Customer Churn Prediction ...
# 4  FinancePy: A Comprehensive Python Library for ...
#
#                                                  url  published_date  \
# 0  https://shyambhu20.blogspot.com/2025/04/unders...             NaN
# 1  https://shyambhu20.blogspot.com/2024/09/20-mus...             NaN
# 2  https://shyambhu20.blogspot.com/2024/09/a-look...             NaN
# 3  https://shyambhu20.blogspot.com/2024/09/Case-s...             NaN
# 4  https://shyambhu20.blogspot.com/2024/09/financ...             NaN
#
#                                                 text
# 0  Certainly! Here's a comprehensive blog post th...
# 1  Introduction:\n \nWhen preparing for a data sc...
# 2  To have a solid foundation in \nprobability th...
# ...

# %%
dfs = [
    df_1, df_2, df_3, df_4, df_5,
    df_ai_ml, df_arxiv, df_datascienceplus, df_shyambhu
]
# Combine all DataFrames into one
df_merged = pd.concat(dfs, ignore_index=True)

# %%
df_merged.info()
df_merged.head()

df_merged.to_csv("datasets/merged_articles.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           1517 non-null   object
#  1   url             1517 non-null   object
#  2   word_count      1364 non-null   float64
#  3   content         1311 non-null   object
#  4   Title           2484 non-null   object
#  5   Content         2483 non-null   object
#  6   URL             484 non-null    object
#  7   Date            484 non-null    object
#  8   published_date  0 non-null      float64
#  9   text            153 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 312.7+ KB

# %%
df_merged.duplicated().sum()  # Check for duplicates
# Out:
# 0
